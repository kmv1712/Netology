# %%
import requests
import time
import json

# %%
user_id = 171691064 
access_token = "5dfd6b0dee902310df772082421968f4c06443abecbc082a8440cb18910a56daca73ac8d04b25154a1128"

# %%
def get_list_of_not_deleted_or_banned_friends():
    method = 'friends.get'
    url = 'https://api.vk.com/method/' + method
    params = {
        'user_id' : user_id,
        'access_token': access_token
    }

    response_method_friends = requests.get(url, params ).json()
    print('-------------------------------------')
    # print(response_method_friends ['response'])

    list_of_not_deleted_or_banned_friends = []
    for friend in response_method_friends ['response']:
        # print(friend)
        method = 'users.get'
        url = 'https://api.vk.com/method/' + method
        params = {
            'user_id': friend,
            'access_token': access_token
        }
        response = requests.get(url, params).json()
        time.sleep(0.1)
#         print(response)
        try:
            value = response['response'][0]['deactivated']
        except KeyError:
            list_of_not_deleted_or_banned_friends.append(friend)
    #         print('-')
    #         print(response)
    #     for item in response['response'][0]:
    #         if (item != 'deactivated'):
    #             list_of_not_deleted_or_banned_friends.append(friend)
    print('-')
#     print (list_of_not_deleted_or_banned_friends)
    return list_of_not_deleted_or_banned_friends

# %%
get_list_of_not_deleted_or_banned_friends()
# Out:
# -------------------------------------
# {'response': [{'uid': 4929, 'first_name': 'Юрий', 'last_name': 'Калинин'}]}
# {'response': [{'uid': 7858, 'first_name': 'Александр', 'last_name': 'Киракозов'}]}
# {'response': [{'uid': 11952, 'first_name': 'Наталья', 'last_name': 'Павловская'}]}
# {'response': [{'uid': 71295, 'first_name': 'Вера', 'last_name': 'Оленникова'}]}
# {'response': [{'uid': 71491, 'first_name': 'Алёна', 'last_name': 'Смирнова'}]}
# {'response': [{'uid': 75458, 'first_name': 'Кирка', 'last_name': 'Меркушевски'}]}
# {'response': [{'uid': 78540, 'first_name': 'Ivan', 'last_name': 'Karaman'}]}
# {'response': [{'uid': 105932, 'first_name': 'Melony', 'last_name': 'Watter'}]}
# {'response': [{'uid': 143611, 'first_name': 'Юля', 'last_name': 'Вавилина'}]}
# {'response': [{'uid': 144253, 'first_name': 'Екатерина', 'last_name': 'Романова'}]}
# {'response': [{'uid': 214895, 'first_name': 'Антон', 'last_name': 'Цыганов'}]}
# {'response': [{'uid': 317799, 'first_name': 'Лида', 'last_name': 'Перовская'}]}
# {'response': [{'uid': 659299, 'first_name': 'Сергей', 'last_name': 'Гремяченский'}]}
# {'response': [{'uid': 659436, 'first_name': 'Инна', 'last_name': 'Филатова'}]}
# {'response': [{'uid': 662584, 'first_name': 'Катерина', 'last_name': 'Мешкова'}]}
# {'response': [{'uid': 673741, 'first_name': 'Егор', 'last_name': 'Гошин'}]}
# {'response': [{'uid': 692250, 'first_name': 'Алексей', 'last_name': 'Зверев'}]}
# {'response': [{'uid': 768496, 'first_name': 'Саша', 'last_name': 'Чаще'}]}
# {'response': [{'uid': 787463, 'first_name': 'Владимир', 'last_name': 'Поляков'}]}
# {'response': [{'uid': 788652, 'first_name': 'Юрий', 'last_name': 'Виноградов'}]}
# {'response': [{'uid': 855521, 'first_name': 'Anastasia', 'last_name': 'Osnitskaya'}]}
# {'response': [{'uid': 911031, 'first_name': 'Роман', 'last_name': 'Шевченко'}]}
# {'response': [{'uid': 913182, 'first_name': 'Игорь', 'last_name': 'Шергин'}]}
# {'response': [{'uid': 999522, 'first_name': 'Алексей', 'last_name': 'Вовк'}]}
# {'response': [{'uid': 1032766, 'first_name': 'Ольга', 'last_name': 'Тужилкова'}]}
# {'response': [{'uid': 1134398, 'first_name': 'Антон', 'last_name': 'Тампель'}]}
# {'response': [{'uid': 1246368, 'first_name': 'Тимур', 'last_name': 'Калимулин'}]}
# {'response': [{'uid': 1339341, 'first_name': 'Юлия', 'last_name': 'Подсухина'}]}
# {'response': [{'uid': 1367530, 'first_name': 'Светлана', 'last_name': 'Акимова'}]}
# {'response': [{'uid': 1440049, 'first_name': 'Петр', 'last_name': 'Полежаев'}]}
# {'response': [{'uid': 1471450, 'first_name': 'Денис', 'last_name': 'Мухаметьянов'}]}
# {'response': [{'uid': 1646659, 'first_name': 'Софья', 'last_name': 'Спяльс'}]}
# {'response': [{'uid': 1763623, 'first_name': 'Роман', 'last_name': 'Волынчук'}]}
# {'response': [{'uid': 1766644, 'first_name': 'Игорь', 'last_name': 'Бессмертный'}]}
# {'response': [{'uid': 1809780, 'first_name': 'Эля', 'last_name': 'Морковина'}]}
# {'response': [{'uid': 2062117, 'first_name': 'Антон', 'last_name': 'Ягельницкий'}]}
# {'response': [{'uid': 2086139, 'first_name': 'Михаил', 'last_name': 'Добровольский'}]}
# {'response': [{'uid': 2090146, 'first_name': 'Роман', 'last_name': 'Матанцев'}]}
# {'response': [{'uid': 2456344, 'first_name': 'Рамиль', 'last_name': 'Шайхутдинов'}]}
# {'response': [{'uid': 2559236, 'first_name': 'Сева', 'last_name': 'Толстопятов'}]}
# {'response': [{'uid': 2562369, 'first_name': 'Денис', 'last_name': 'Поздняков'}]}
# {'response': [{'uid': 2657088, 'first_name': 'Мария', 'last_name': 'Ефремова'}]}
# {'response': [{'uid': 2705957, 'first_name': 'Даниил', 'last_name': 'Гладких'}]}
# {'response': [{'uid': 2711121, 'first_name': 'Нюся', 'last_name': 'Грудина'}]}
# {'response': [{'uid': 2752341, 'first_name': 'Марта', 'last_name': 'Мезенина'}]}
# {'response': [{'uid': 2809629, 'first_name': 'Miroslav', 'last_name': 'Dralo'}]}
# {'response': [{'uid': 2912707, 'first_name': 'Сергей', 'last_name': 'Белозоров'}]}
# {'response': [{'uid': 3076020, 'first_name': 'Макс', 'last_name': 'Жуков'}]}
# {'response': [{'uid': 3551352, 'first_name': 'Никита', 'last_name': 'Шмаков'}]}
# {'response': [{'uid': 3563036, 'first_name': 'Лев', 'last_name': 'Плинер', 'deactivated': 'deleted'}]}
# {'response': [{'uid': 3636234, 'first_name': 'Леонид', 'last_name': 'Легашёв'}]}
# {'response': [{'uid': 3858793, 'first_name': 'Алексей', 'last_name': 'Патосин'}]}
# {'response': [{'uid': 5165523, 'first_name': 'Василиса', 'last_name': 'Покинутыйсолнцем-Готишный'}]}
# {'response': [{'uid': 5527094, 'first_name': 'Линара', 'last_name': 'Ли'}]}
# {'response': [{'uid': 5561531, 'first_name': 'Ярослав', 'last_name': 'Агарков'}]}
# {'response': [{'uid': 5727022, 'first_name': 'Алевтина', 'last_name': 'Лучинкина'}]}
# {'response': [{'uid': 6099111, 'first_name': 'Алексей', 'last_name': 'Павленко'}]}
# {'response': [{'uid': 6152449, 'first_name': 'Иван', 'last_name': 'Синицын'}]}
# {'response': [{'uid': 6215299, 'first_name': 'Наиль', 'last_name': 'Салихов'}]}
# {'response': [{'uid': 6334999, 'first_name': 'Георгий', 'last_name': 'Кошелев'}]}
# {'response': [{'uid': 6433503, 'first_name': 'Маргаритка', 'last_name': 'Шадрина'}]}
# {'response': [{'uid': 6821814, 'first_name': 'Дамирик', 'last_name': 'Вагизов'}]}
# {'response': [{'uid': 7443583, 'first_name': 'Вадим', 'last_name': 'Вайнштейн'}]}
# {'response': [{'uid': 7776415, 'first_name': 'Дмитрий', 'last_name': 'Пудло'}]}
# {'response': [{'uid': 7840937, 'first_name': 'Екатерина', 'last_name': 'Полякова'}]}
# {'response': [{'uid': 8219833, 'first_name': 'Владимир', 'last_name': 'Белянин'}]}
# {'response': [{'uid': 9470247, 'first_name': 'Ростислав', 'last_name': 'Поляк'}]}
# {'response': [{'uid': 9889116, 'first_name': 'Даша', 'last_name': 'Сметанина'}]}
# {'response': [{'uid': 10684633, 'first_name': 'Надежда', 'last_name': 'Денисова'}]}
# {'response': [{'uid': 10875152, 'first_name': 'Анна', 'last_name': 'Горелик'}]}
# {'response': [{'uid': 11364269, 'first_name': 'Евгения', 'last_name': 'Губарева'}]}
# {'response': [{'uid': 11479238, 'first_name': 'Ирина', 'last_name': 'Минина'}]}
# {'response': [{'uid': 11986689, 'first_name': 'Ольга', 'last_name': 'Кириллова'}]}
# {'response': [{'uid': 12941980, 'first_name': 'Павел', 'last_name': 'Гайсин'}]}
# {'response': [{'uid': 13122477, 'first_name': 'Людмила', 'last_name': 'Кубарева'}]}
# {'response': [{'uid': 13335254, 'first_name': 'Артём', 'last_name': 'Поляков'}]}
# {'response': [{'uid': 13763476, 'first_name': 'Слава', 'last_name': 'Лыкова'}]}
# {'response': [{'uid': 14230616, 'first_name': 'Андрей', 'last_name': 'Лыков'}]}
# {'response': [{'uid': 14550543, 'first_name': 'Лилия', 'last_name': 'Алимбекова'}]}
# {'response': [{'uid': 14704667, 'first_name': 'Екатерина', 'last_name': 'Романова'}]}
# {'response': [{'uid': 15164302, 'first_name': 'Александр', 'last_name': 'Мочалин'}]}
# {'response': [{'uid': 15258454, 'first_name': 'Денис', 'last_name': 'Панферов'}]}
# {'response': [{'uid': 15431923, 'first_name': 'Александр', 'last_name': 'Голубев'}]}
# {'response': [{'uid': 16026849, 'first_name': 'Маша', 'last_name': 'Гаврина'}]}
# {'response': [{'uid': 16232197, 'first_name': 'Саша', 'last_name': 'Бизиков'}]}
# {'response': [{'uid': 16244955, 'first_name': 'Николай', 'last_name': 'Макеев'}]}
# {'response': [{'uid': 16599580, 'first_name': 'Лена', 'last_name': 'Шмаргунова'}]}
# {'response': [{'uid': 16761062, 'first_name': 'Павел', 'last_name': 'Штанько'}]}
# {'response': [{'uid': 16892193, 'first_name': 'Юлия', 'last_name': 'Музафарова'}]}
# {'response': [{'uid': 17488975, 'first_name': 'Полина', 'last_name': 'Горковцева-Пантюхина'}]}
# {'response': [{'uid': 17650760, 'first_name': 'Филипп', 'last_name': 'Жинкин'}]}
# {'response': [{'uid': 17962268, 'first_name': 'Маша', 'last_name': 'Рудниченко'}]}
# {'response': [{'uid': 18062307, 'first_name': 'Анастасия', 'last_name': 'Михайлова'}]}
# {'response': [{'uid': 18196828, 'first_name': 'Алексей', 'last_name': 'Баталин'}]}
# {'response': [{'uid': 19832321, 'first_name': 'Евгения', 'last_name': 'Быкова'}]}
# {'response': [{'uid': 20272794, 'first_name': 'Павел', 'last_name': 'Иванов'}]}
# {'response': [{'uid': 20488230, 'first_name': 'Александр', 'last_name': 'Шухман'}]}
# {'response': [{'uid': 21198190, 'first_name': 'Серёга', 'last_name': 'Ракитин'}]}
# {'response': [{'uid': 21283573, 'first_name': 'Данил', 'last_name': 'Фомин'}]}
# {'response': [{'uid': 22879376, 'first_name': 'Александр', 'last_name': 'Гуляев'}]}
# {'response': [{'uid': 25598114, 'first_name': 'Роман', 'last_name': 'Метёлкин'}]}
# {'response': [{'uid': 26274755, 'first_name': 'Владимир', 'last_name': 'Изволь'}]}
# {'response': [{'uid': 32353261, 'first_name': 'Антон', 'last_name': 'Дмитриев'}]}
# {'response': [{'uid': 32744834, 'first_name': 'Гульназ', 'last_name': 'Айбулатова'}]}
# {'response': [{'uid': 33769451, 'first_name': 'Наташа', 'last_name': 'Белай'}]}
# {'response': [{'uid': 41016241, 'first_name': 'Дмитрий', 'last_name': 'Покревский'}]}
# {'response': [{'uid': 41475773, 'first_name': 'Газим', 'last_name': 'Мухамедьяров'}]}
# {'response': [{'uid': 42609976, 'first_name': 'Ильмир', 'last_name': 'Кудабаев'}]}
# {'response': [{'uid': 46298639, 'first_name': 'Миша', 'last_name': 'Владимиров'}]}
# {'response': [{'uid': 46370315, 'first_name': 'Иван', 'last_name': 'Иванов'}]}
# {'response': [{'uid': 46680193, 'first_name': 'Алексей', 'last_name': 'Денисов'}]}
# {'response': [{'uid': 48102502, 'first_name': 'Евгений', 'last_name': 'Маляров'}]}
# {'response': [{'uid': 49396083, 'first_name': 'Роман', 'last_name': 'Теличкин'}]}
# {'response': [{'uid': 52262270, 'first_name': 'Юлия', 'last_name': 'Кашапова'}]}
# {'response': [{'uid': 52612027, 'first_name': 'Любовь', 'last_name': 'Адрова'}]}
# {'response': [{'uid': 54632388, 'first_name': 'Le', 'last_name': 'Soleil'}]}
# {'response': [{'uid': 57052402, 'first_name': 'Александр', 'last_name': 'Будиков'}]}
# {'response': [{'uid': 58798893, 'first_name': 'Дарья', 'last_name': 'Ческидова-Феофанова'}]}
# {'response': [{'uid': 59648648, 'first_name': 'Петр', 'last_name': 'Савельев'}]}
# {'response': [{'uid': 62063198, 'first_name': 'Вячеслав', 'last_name': 'Щербаков'}]}
# {'response': [{'uid': 62933544, 'first_name': 'Гузель', 'last_name': 'Иргалина'}]}
# {'response': [{'uid': 64626974, 'first_name': 'Максим', 'last_name': 'Объедков'}]}
# {'response': [{'uid': 65081354, 'first_name': 'Bazzz', 'last_name': 'Готишный'}]}
# {'response': [{'uid': 65359751, 'first_name': 'Евгений', 'last_name': 'Романенко'}]}
# {'response': [{'uid': 77862315, 'first_name': 'Мария', 'last_name': 'Кокаия'}]}
# {'response': [{'uid': 79101880, 'first_name': 'Иван', 'last_name': 'Унру'}]}
# {'response': [{'uid': 83654550, 'first_name': 'Андрей', 'last_name': 'Солдатов'}]}
# {'response': [{'uid': 85184665, 'first_name': 'Александр', 'last_name': 'Мицук'}]}
# {'response': [{'uid': 88305738, 'first_name': 'Анна', 'last_name': 'Абель'}]}
# {'response': [{'uid': 88359019, 'first_name': 'Татьяна', 'last_name': 'Мицук'}]}
# {'response': [{'uid': 93179895, 'first_name': 'Андрей', 'last_name': 'Гапонов'}]}
# {'response': [{'uid': 97172348, 'first_name': 'Alexander', 'last_name': 'K.'}]}
# {'response': [{'uid': 110553958, 'first_name': 'Tim', 'last_name': 'Tuktagulov'}]}
# {'response': [{'uid': 128251264, 'first_name': 'Сергей', 'last_name': 'Миронов'}]}
# {'response': [{'uid': 132411195, 'first_name': 'Владимир', 'last_name': 'Котченко'}]}
# {'response': [{'uid': 134994318, 'first_name': 'Роман', 'last_name': 'Киселёв', 'deactivated': 'deleted'}]}
# {'response': [{'uid': 142965761, 'first_name': 'Юлия', 'last_name': 'Солдатенко'}]}
# {'response': [{'uid': 152062439, 'first_name': 'Сашка', 'last_name': 'Адекватных'}]}
# {'response': [{'uid': 152746319, 'first_name': 'Александр', 'last_name': 'Филатов'}]}
# {'response': [{'uid': 153933504, 'first_name': 'Annet', 'last_name': 'Gieseking'}]}
# {'response': [{'uid': 155686070, 'first_name': 'Макс', 'last_name': 'Ордин', 'deactivated': 'deleted'}]}
# {'response': [{'uid': 161468248, 'first_name': 'Сергей', 'last_name': 'Клименков'}]}
# {'response': [{'uid': 163954112, 'first_name': 'Вечер', 'last_name': 'Песен'}]}
# {'response': [{'uid': 171917250, 'first_name': 'Александр', 'last_name': 'Пономарёв'}]}
# {'response': [{'uid': 173110550, 'first_name': 'Анастасия', 'last_name': 'Гуменникова'}]}
# {'response': [{'uid': 173884854, 'first_name': 'Елизавета', 'last_name': 'Миронова', 'deactivated': 'banned'}]}
# {'response': [{'uid': 175707944, 'first_name': 'Sergey', 'last_name': 'Kazakov'}]}
# {'response': [{'uid': 184688820, 'first_name': 'Дмитрий', 'last_name': 'Турчев'}]}
# {'response': [{'uid': 193126555, 'first_name': 'Юлия', 'last_name': 'Солдатенко'}]}
# {'response': [{'uid': 208537381, 'first_name': 'Эльнур', 'last_name': 'Асадов'}]}
# {'response': [{'uid': 223235705, 'first_name': 'Saint', 'last_name': 'Saint'}]}
# {'response': [{'uid': 227029485, 'first_name': 'Tim', 'last_name': 'Tuktagulov'}]}
# {'response': [{'uid': 229416595, 'first_name': 'Vjacheslav', 'last_name': 'Gluhov'}]}
# {'response': [{'uid': 231842339, 'first_name': 'Полина', 'last_name': 'Миронова'}]}
# {'response': [{'uid': 237468206, 'first_name': 'Андрей', 'last_name': 'Шмаргунов'}]}
# {'response': [{'uid': 252091764, 'first_name': 'Михаил', 'last_name': 'Марар'}]}
# {'response': [{'uid': 255838606, 'first_name': 'Игорек', 'last_name': 'Буторин'}]}
# {'response': [{'uid': 283037583, 'first_name': 'Сергей', 'last_name': 'Карпов'}]}
# {'response': [{'uid': 300349200, 'first_name': 'Людмила', 'last_name': 'Кубарева'}]}
# {'response': [{'uid': 340887494, 'first_name': 'Римма', 'last_name': 'Шмаргунова'}]}
# {'response': [{'uid': 379188930, 'first_name': 'Андрей', 'last_name': 'Шмаргунов'}]}
# {'response': [{'uid': 401466040, 'first_name': 'Андрей', 'last_name': 'Шмаргунов'}]}
# {'response': [{'uid': 417989532, 'first_name': 'Евгений', 'last_name': 'Петрович', 'deactivated': 'deleted'}]}
# {'response': [{'uid': 434109816, 'first_name': 'Римма', 'last_name': 'Шмаргунова'}]}
# {'response': [{'uid': 437280430, 'first_name': 'Elizaveta', 'last_name': 'Mironova'}]}
# [4929,
#  7858,
#  11952,
#  71295,
#  71491,
#  75458,
#  78540,
#  105932,
#  143611,
#  144253,
#  214895,
#  317799,
#  659299,
#  659436,
#  662584,
#  673741,
#  692250,
#  768496,
#  787463,
#  788652,
#  855521,
#  911031,
#  913182,
#  999522,
#  1032766,
#  1134398,
#  1246368,
#  1339341,
#  1367530,
#  1440049,
#  1471450,
#  1646659,
#  1763623,
#  1766644,
#  1809780,
#  2062117,
#  2086139,
#  2090146,
#  2456344,
#  2559236,
#  2562369,
#  2657088,
#  2705957,
#  2711121,
#  2752341,
#  2809629,
#  2912707,
#  3076020,
#  3551352,
#  3636234,
#  3858793,
#  5165523,
#  5527094,
#  5561531,
#  5727022,
#  6099111,
#  6152449,
#  6215299,
#  6334999,
#  6433503,
#  6821814,
#  7443583,
#  7776415,
#  7840937,
#  8219833,
#  9470247,
#  9889116,
#  10684633,
#  10875152,
#  11364269,
#  11479238,
#  11986689,
#  12941980,
#  13122477,
#  13335254,
#  13763476,
#  14230616,
#  14550543,
#  14704667,
#  15164302,
#  15258454,
#  15431923,
#  16026849,
#  16232197,
#  16244955,
#  16599580,
#  16761062,
#  16892193,
#  17488975,
#  17650760,
#  17962268,
#  18062307,
#  18196828,
#  19832321,
#  20272794,
#  20488230,
#  21198190,
#  21283573,
#  22879376,
#  25598114,
#  26274755,
#  32353261,
#  32744834,
#  33769451,
#  41016241,
#  41475773,
#  42609976,
#  46298639,
#  46370315,
#  46680193,
#  48102502,
#  49396083,
#  52262270,
#  52612027,
#  54632388,
#  57052402,
#  58798893,
#  59648648,
#  62063198,
#  62933544,
#  64626974,
#  65081354,
#  65359751,
#  77862315,
#  79101880,
#  83654550,
#  85184665,
#  88305738,
#  88359019,
#  93179895,
#  97172348,
#  110553958,
#  128251264,
#  132411195,
#  142965761,
#  152062439,
#  152746319,
#  153933504,
#  161468248,
#  163954112,
#  171917250,
#  173110550,
#  175707944,
#  184688820,
#  193126555,
#  208537381,
#  223235705,
#  227029485,
#  229416595,
#  231842339,
#  237468206,
#  252091764,
#  255838606,
#  283037583,
#  300349200,
#  340887494,
#  379188930,
#  401466040,
#  434109816,
#  437280430]

# %%
def get_list_of_all_groups_of_friends():    
    list_of_all_groups_of_friends = []
    for friend in list_of_not_deleted_or_banned_friends:
        # print(friend)
        method = 'groups.get'
        url = 'https://api.vk.com/method/' + method
        params = {
            'user_id': friend,
            'access_token': access_token
        }
        time.sleep(0.1)
        response = requests.get(url, params).json()
        try:
            value = response['response']
        except KeyError:
            response['response'] = [0]
    #     print(response['response'])
    #     print('---------') 
        list_of_all_groups_of_friends.append(response['response'])

    # print (list_of_all_groups_of_friends)
#     print (sum(list_of_all_groups_of_friends, []))
    list_of_all_groups_of_friends = sum(list_of_all_groups_of_friends, [])
    print('--')
    return list_of_all_groups_of_friends

# %%
get_list_of_all_groups_of_friends()
# Out:
# --
# [57269118,
#  154911672,
#  145001302,
#  78638180,
#  155668977,
#  38969789,
#  31976785,
#  35294456,
#  31691361,
#  36671206,
#  146367691,
#  32370614,
#  120689067,
#  74595166,
#  25240087,
#  52347284,
#  31480508,
#  29534144,
#  27058070,
#  56106344,
#  24946565,
#  47967522,
#  151300334,
#  70232735,
#  19789249,
#  36851569,
#  35712861,
#  59833636,
#  40836944,
#  26270763,
#  39509143,
#  66317817,
#  33172903,
#  43234662,
#  36507793,
#  65960786,
#  106631887,
#  38685014,
#  48319873,
#  938210,
#  4537617,
#  6979865,
#  11283947,
#  19167076,
#  20793074,
#  23282484,
#  23485253,
#  23509777,
#  23750039,
#  23758226,
#  25336774,
#  25440153,
#  25613643,
#  26456494,
#  26495743,
#  26513373,
#  26589302,
#  26649138,
#  26776509,
#  27886944,
#  27922438,
#  28492612,
#  29370288,
#  29559271,
#  29973665,
#  30022666,
#  30192213,
#  30525261,
#  30622286,
#  30760683,
#  30947244,
#  31554488,
#  31982622,
#  32521545,
#  32612750,
#  32975834,
#  33028522,
#  33491625,
#  33913959,
#  33964060,
#  34397905,
#  35242910,
#  35285306,
#  35378542,
#  35555559,
#  35813995,
#  35828815,
#  36250705,
#  36658204,
#  36937391,
#  37156391,
#  37169648,
#  37276776,
#  38210991,
#  38598326,
#  38663377,
#  39615703,
#  39706234,
#  39846813,
#  39982632,
#  40301846,
#  40794778,
#  41126705,
#  41194531,
#  41835403,
#  42668984,
#  42868413,
#  43001537,
#  43757247,
#  44064378,
#  44366611,
#  46211765,
#  46860100,
#  47230001,
#  47515637,
#  47812855,
#  49420393,
#  49489389,
#  51175007,
#  51199719,
#  51873373,
#  53404312,
#  53998807,
#  55513497,
#  57659973,
#  57846937,
#  59156573,
#  60252191,
#  60526935,
#  60550612,
#  60667229,
#  61321075,
#  61651157,
#  61828602,
#  62292897,
#  64828184,
#  64927236,
#  65711848,
#  65925942,
#  68052487,
#  68309986,
#  68749827,
#  69399387,
#  72383889,
#  72467903,
#  72605916,
#  72884889,
#  73625247,
#  73804972,
#  73893149,
#  74404187,
#  75726178,
#  78037666,
#  79098077,
#  82339918,
#  86397700,
#  86443312,
#  93950003,
#  96591297,
#  99929301,
#  103319091,
#  111024898,
#  112454349,
#  113781359,
#  121299932,
#  132842422,
#  140218875,
#  150502570,
#  0,
#  11283947,
#  28569125,
#  57722658,
#  14060510,
#  57659973,
#  38228859,
#  13737032,
#  12545,
#  28941412,
#  44016343,
#  11856785,
#  93269473,
#  65337727,
#  8261999,
#  107331706,
#  33374477,
#  57226628,
#  68759633,
#  57643211,
#  39674240,
#  49336104,
#  1194300,
#  127913837,
#  13651558,
#  100448870,
#  53889359,
#  49510,
#  111097464,
#  20352642,
#  12061253,
#  38116507,
#  4096,
#  60684912,
#  389767,
#  157905999,
#  71833023,
#  965097,
#  148012016,
#  114863321,
#  11783574,
#  152534925,
#  53815798,
#  69737388,
#  155803782,
#  129798237,
#  74702006,
#  132264466,
#  44241660,
#  92429,
#  37654037,
#  69735121,
#  9285222,
#  92064904,
#  88351424,
#  3954652,
#  98162035,
#  1158885,
#  22560272,
#  82634004,
#  81302256,
#  107859405,
#  16167373,
#  152224623,
#  49984493,
#  84867573,
#  42920502,
#  79912763,
#  41001742,
#  148244075,
#  146214078,
#  26112764,
#  71273824,
#  75774297,
#  71612945,
#  128657600,
#  92505930,
#  103298259,
#  35669235,
#  71732090,
#  35607458,
#  56962774,
#  68295532,
#  61906799,
#  60124226,
#  87396564,
#  56118001,
#  36920294,
#  11283947,
#  68471405,
#  35156109,
#  50684204,
#  53744890,
#  24295808,
#  46761002,
#  25649071,
#  32407793,
#  29302425,
#  60550537,
#  23988464,
#  20629724,
#  11283947,
#  4569,
#  76476494,
#  30022666,
#  75808486,
#  30666517,
#  26270763,
#  84293539,
#  53076419,
#  32754081,
#  36243788,
#  24565142,
#  36045680,
#  32295218,
#  42358972,
#  3305,
#  16986287,
#  76656691,
#  2158488,
#  3973096,
#  22822305,
#  27395059,
#  27958051,
#  28976288,
#  31902369,
#  32194285,
#  36184135,
#  36315046,
#  37684434,
#  42541008,
#  49680000,
#  77500775,
#  20225241,
#  35115483,
#  0,
#  27932995,
#  63731512,
#  55754229,
#  91050183,
#  38187378,
#  48149358,
#  76027171,
#  1239834,
#  4547702,
#  93223931,
#  23351349,
#  40188395,
#  88705863,
#  138340519,
#  47000084,
#  47973732,
#  57527372,
#  72889683,
#  78790613,
#  98609808,
#  30022666,
#  28950133,
#  23378353,
#  27902394,
#  25117353,
#  30525261,
#  26970810,
#  31072900,
#  27637181,
#  31333866,
#  28938560,
#  22558194,
#  3785,
#  42763042,
#  439,
#  30179770,
#  49840023,
#  16979732,
#  27680436,
#  51362846,
#  11982368,
#  45661658,
#  26217154,
#  49684148,
#  26270763,
#  36338110,
#  33393308,
#  28261334,
#  12141758,
#  5445504,
#  30666517,
#  29564611,
#  33755370,
#  25723017,
#  17745174,
#  23684028,
#  2251146,
#  826,
#  5041614,
#  174209,
#  34938229,
#  54530371,
#  37726129,
#  714,
#  28871588,
#  632045,
#  37579890,
#  46101364,
#  16108331,
#  36209322,
#  15955496,
#  43503600,
#  38000487,
#  39729087,
#  40405598,
#  4423,
#  485731,
#  5751308,
#  35524891,
#  255391,
#  37234340,
#  67207138,
#  3601199,
#  12994512,
#  7134,
#  12310748,
#  9388212,
#  28,
#  17733403,
#  18794783,
#  46603036,
#  2709,
#  15918043,
#  160227,
#  5512,
#  73578636,
#  16436783,
#  679011,
#  42706552,
#  1095659,
#  8962,
#  51566949,
#  5741,
#  28587408,
#  507444,
#  42496831,
#  9883830,
#  94,
#  658,
#  43689127,
#  27938604,
#  34196141,
#  31275926,
#  49110120,
#  23730054,
#  25997323,
#  10064822,
#  36322853,
#  265251,
#  49466225,
#  30825867,
#  31206244,
#  9059081,
#  41889708,
#  16514314,
#  35861406,
#  24882091,
#  35156109,
#  37922,
#  4834555,
#  32017543,
#  20587615,
#  47738246,
#  55891271,
#  40479090,
#  28941412,
#  3500,
#  63054301,
#  28513014,
#  43157549,
#  718894,
#  35519113,
#  44229922,
#  15620149,
#  34197962,
#  34421263,
#  9834130,
#  52392743,
#  11627716,
#  19474185,
#  15703987,
#  36101605,
#  28756990,
#  11590634,
#  11059,
#  66609,
#  70122581,
#  60249235,
#  52512846,
#  58077614,
#  12764821,
#  72080288,
#  47419208,
#  12382470,
#  6718896,
#  2499902,
#  23297,
#  78365865,
#  727675,
#  38265510,
#  25739561,
#  32581846,
#  14330,
#  10740309,
#  12328630,
#  8938143,
#  44884061,
#  8544,
#  2412709,
#  25297429,
#  33468739,
#  25508622,
#  55660507,
#  32185956,
#  67233436,
#  30039770,
#  20363211,
#  26348326,
#  51884282,
#  26277718,
#  75025032,
#  40761712,
#  59426554,
#  33151951,
#  28809886,
#  5527455,
#  214878,
#  42692205,
#  7134282,
#  50684204,
#  23791221,
#  16460395,
#  1949,
#  14879623,
#  59392917,
#  72013221,
#  119331108,
#  33773,
#  7548777,
#  412826,
#  4093753,
#  37963030,
#  51501263,
#  5986653,
#  16625009,
#  124629,
#  74851450,
#  38906049,
#  76088560,
#  65474186,
#  65924162,
#  85857911,
#  91723918,
#  74056115,
#  79255207,
#  50060615,
#  112851385,
#  61918974,
#  41173762,
#  2518548,
#  26225,
#  7796,
#  64760972,
#  51286771,
#  49288226,
#  27650946,
#  53779328,
#  69859206,
#  51854217,
#  4466311,
#  101488283,
#  47028274,
#  27045470,
#  9586502,
#  88188612,
#  33140836,
#  117874628,
#  92759916,
#  64559392,
#  138643559,
#  4044681,
#  38136601,
#  95095293,
#  73769778,
#  644236,
#  14842582,
#  32215854,
#  59898686,
#  23177813,
#  77366439,
#  12703,
#  73683136,
#  91053037,
#  28865802,
#  31459134,
#  60890114,
#  9665681,
#  29312771,
#  73997187,
#  68424223,
#  88930546,
#  71187312,
#  69938,
#  31361,
#  101860066,
#  60296795,
#  74012013,
#  20570359,
#  49430499,
#  1558176,
#  54978987,
#  53555199,
#  127243237,
#  21050,
#  85946068,
#  35586009,
#  102961727,
#  108353269,
#  16531909,
#  77662737,
#  604,
#  37440180,
#  23923637,
#  54458119,
#  149440199,
#  8358,
#  165374,
#  4081520,
#  2148020,
#  34996168,
#  63012848,
#  69762315,
#  104637065,
#  8830879,
#  100928767,
#  32625617,
#  5605716,
#  92481084,
#  20906642,
#  78800317,
#  883672,
#  199479,
#  36810111,
#  2931,
#  288362,
#  131734184,
#  84079432,
#  19868024,
#  81791728,
#  39909687,
#  87043947,
#  78381259,
#  5215181,
#  78833662,
#  99519467,
#  3592776,
#  85795884,
#  5689389,
#  73495942,
#  106229427,
#  106947779,
#  107094478,
#  90464500,
#  102610200,
#  102521017,
#  133742765,
#  80002864,
#  81980926,
#  64549370,
#  43290912,
#  88782937,
#  100856073,
#  62735827,
#  26664192,
#  48253941,
#  48252958,
#  134302781,
#  69506645,
#  75255732,
#  35648054,
#  74910636,
#  88083488,
#  56704259,
#  73155848,
#  25829975,
#  967033,
#  4087334,
#  82967566,
#  53783284,
#  28058032,
#  10088102,
#  32393043,
#  20629724,
#  56905360,
#  100614614,
#  26270763,
#  29559271,
#  3948346,
#  32041317,
#  30022666,
#  64580175,
#  125741767,
#  56595481,
#  116863980,
#  11283947,
#  47028954,
#  61157179,
#  33489538,
#  31862851,
#  42541008,
#  36775085,
#  26776509,
#  55326998,
#  7965562,
#  28698967,
#  33803304,
#  108468,
#  126093223,
#  16824047,
#  21118635,
#  86529522,
#  67940544,
#  11283947,
#  25882042,
#  14060510,
#  28587408,
#  94,
#  78682645,
#  84793390,
#  154631231,
#  147415323,
#  17796776,
#  2878,
#  48681783,
#  41208167,
#  45660640,
#  1530671,
#  19412423,
#  74249779,
#  118,
#  44001716,
#  125266264,
#  222235,
#  137783190,
#  139722629,
#  94359346,
#  145248025,
#  31119059,
#  47546906,
#  97819925,
#  63282215,
#  4344135,
#  63042205,
#  73843185,
#  61226939,
#  86885698,
#  145547973,
#  104891203,
#  76558788,
#  131616069,
#  76715418,
#  12922001,
#  155683086,
#  89377146,
#  66422738,
#  147534852,
#  76507013,
#  152089138,
#  82293907,
#  129424562,
#  72698,
#  138582625,
#  112504377,
#  154957478,
#  146684133,
#  121096210,
#  113415545,
#  287808,
#  152522040,
#  199622,
#  152990826,
#  127421002,
#  128042,
#  147695002,
#  29468395,
#  35486626,
#  22798006,
#  29246653,
#  29559271,
#  34384434,
#  30022666,
#  12648877,
#  65960786,
#  491,
#  25153764,
#  35349905,
#  16979732,
#  15323631,
#  29231851,
#  77521,
#  68995594,
#  35238813,
#  63731512,
#  21118635,
#  154239,
#  624,
#  40886007,
#  6507719,
#  159882,
#  35683607,
#  30598666,
#  1980,
#  4829,
#  84752433,
#  268980,
#  10683660,
#  80093334,
#  683495,
#  13302,
#  72495085,
#  26179488,
#  6117275,
#  8509,
#  9506061,
#  10055384,
#  1454045,
#  136837,
#  11254710,
#  76456136,
#  26323878,
#  5251193,
#  53358766,
#  2043,
#  83415396,
#  2028,
#  48155,
#  426573,
#  3840605,
#  2591,
#  3213109,
#  6827569,
#  1538,
#  9622446,
#  388036,
#  1607,
#  39777,
#  6031665,
#  5276808,
#  6002,
#  292925,
#  29279015,
#  1153199,
#  10611,
#  9207398,
#  5308,
#  384521,
#  146295,
#  53076,
#  8097177,
#  231339,
#  39387,
#  57840926,
#  69961,
#  3788326,
#  115452,
#  116137627,
#  48826942,
#  79051,
#  61113682,
#  29346547,
#  156486,
#  59778672,
#  1219858,
#  18418170,
#  43093223,
#  50378987,
#  422238,
#  16988075,
#  45949555,
#  13195,
#  20388172,
#  51033647,
#  12027,
#  19529,
#  6664902,
#  73418964,
#  7250324,
#  27669439,
#  6952395,
#  27283,
#  22195,
#  26697094,
#  10118506,
#  14293719,
#  279584,
#  3857886,
#  1465,
#  151257,
#  1808419,
#  412505,
#  2376516,
#  501748,
#  6884564,
#  262970,
#  380982,
#  7786769,
#  58440231,
#  7185562,
#  876,
#  2744788,
#  1132589,
#  21013,
#  17859245,
#  1132426,
#  7191529,
#  23408404,
#  252047,
#  8676,
#  34902440,
#  41086,
#  7718153,
#  8644600,
#  731009,
#  49962,
#  15858907,
#  8829788,
#  10312,
#  509282,
#  268816,
#  22342164,
#  5862810,
#  6945560,
#  3644,
#  31041469,
#  370439,
#  95578179,
#  826378,
#  31995231,
#  55939347,
#  60685606,
#  10991273,
#  2971705,
#  145550154,
#  1804809,
#  16007082,
#  303351,
#  155140,
#  571912,
#  28723767,
#  111651,
#  32210411,
#  289580,
#  19385968,
#  9973791,
#  380935,
#  101881,
#  174093,
#  484093,
#  30431159,
#  2088122,
#  78840411,
#  1177142,
#  3884911,
#  1047564,
#  18501193,
#  6641212,
#  15179830,
#  49361,
#  20699635,
#  10925070,
#  53693756,
#  684795,
#  196724,
#  86780,
#  200165,
#  9203511,
#  348504,
#  77727679,
#  1485438,
#  14879642,
#  124713667,
#  1035756,
#  28896744,
#  8161800,
#  30497,
#  263600,
#  15933572,
#  9794141,
#  8769,
#  8062327,
#  9286301,
#  1411530,
#  24976513,
#  45845213,
#  265635,
#  24832977,
#  823539,
#  375933,
#  5880,
#  9242507,
#  1727927,
#  9972351,
#  43460812,
#  72411342,
#  24159,
#  4729281,
#  93570,
#  127154,
#  1053159,
#  3069198,
#  24748189,
#  2044148,
#  1202748,
#  49658330,
#  26125,
#  657346,
#  80824,
#  4909607,
#  1221913,
#  51437558,
#  283149,
#  3091282,
#  2996299,
#  13767983,
#  2055201,
#  47691,
#  ...]

# %%
def get_user_groups():
    method = 'groups.get'
    url = 'https://api.vk.com/method/' + method
    params = {
        'user_id': user_id,
        'access_token': access_token
    }

    response = requests.get(url, params ).json()
#     print(response['response'])
    user_groups = response['response']
    print('---')
#     print(len(response['response']))
    return user_groups

# %%
get_user_groups()
# Out:
# ---
# [51766355,
#  124656670,
#  4100014,
#  151498735,
#  87389803,
#  8564,
#  30314549,
#  36661515,
#  27683540,
#  35486626]

# %%
def get_unique_groups_user():
    unique_groups_user = []
    for item in set(user_groups).difference(list_of_all_groups_of_friends):
        unique_groups_user.append(item)
#     print (unique_groups_user)
    return unique_groups_user

# %%
get_unique_groups_user()
# Out:
# [36661515, 8564, 124656670]

# %%
def get_final_unique_groups_user():
    final_unique_groups_user = []
    for item in unique_groups_user:
        method = 'groups.getById'
        url = 'https://api.vk.com/method/' + method
        params = {
        'group_id': item,
        'access_token': access_token
        }
        time.sleep(1)
        response = requests.get(url, params ).json()
        final_unique_groups_user.append(response['response'][0])
#     print(final_unique_groups_user)
    return final_unique_groups_user

# %%
get_final_unique_groups_user()
# Out:
# [{'gid': 36661515, 'name': 'Электрофорез', 'screen_name': 'electroforez', 'is_closed': 0, 'type': 'page', 'photo': 'https://pp.userapi.com/c841433/v841433877/2de32/B3-GMjalWLE.jpg', 'photo_medium': 'https://pp.userapi.com/c841433/v841433877/2de31/b0m12sUdHWc.jpg', 'photo_big': 'https://pp.userapi.com/c841433/v841433877/2de30/SE1tnWkH_R8.jpg'}, {'gid': 8564, 'name': 'Synthpop  [Futurepop, Retrowave, Electropop]', 'screen_name': 'synthpop_music', 'is_closed': 0, 'type': 'page', 'photo': 'https://pp.userapi.com/c637224/v637224032/27881/yr_XqliFk7Q.jpg', 'photo_medium': 'https://pp.userapi.com/c637224/v637224032/27880/nOOYFCx7oeI.jpg', 'photo_big': 'https://pp.userapi.com/c637224/v637224032/2787f/75LJO8UMIXM.jpg'}, {'gid': 124656670, 'name': 'Недвижимость в Кудрово', 'screen_name': 'kudrovorealty', 'is_closed': 0, 'type': 'page', 'photo': 'https://pp.userapi.com/c630725/v630725994/41049/AlmpbMvTAd0.jpg', 'photo_medium': 'https://pp.userapi.com/c630725/v630725994/41048/yVm5d6BL0CM.jpg', 'photo_big': 'https://pp.userapi.com/c630725/v630725994/41047/0o-7aWfsJZk.jpg'}]
# [{'gid': 36661515,
#   'is_closed': 0,
#   'name': 'Электрофорез',
#   'photo': 'https://pp.userapi.com/c841433/v841433877/2de32/B3-GMjalWLE.jpg',
#   'photo_big': 'https://pp.userapi.com/c841433/v841433877/2de30/SE1tnWkH_R8.jpg',
#   'photo_medium': 'https://pp.userapi.com/c841433/v841433877/2de31/b0m12sUdHWc.jpg',
#   'screen_name': 'electroforez',
#   'type': 'page'},
#  {'gid': 8564,
#   'is_closed': 0,
#   'name': 'Synthpop  [Futurepop, Retrowave, Electropop]',
#   'photo': 'https://pp.userapi.com/c637224/v637224032/27881/yr_XqliFk7Q.jpg',
#   'photo_big': 'https://pp.userapi.com/c637224/v637224032/2787f/75LJO8UMIXM.jpg',
#   'photo_medium': 'https://pp.userapi.com/c637224/v637224032/27880/nOOYFCx7oeI.jpg',
#   'screen_name': 'synthpop_music',
#   'type': 'page'},
#  {'gid': 124656670,
#   'is_closed': 0,
#   'name': 'Недвижимость в Кудрово',
#   'photo': 'https://pp.userapi.com/c630725/v630725994/41049/AlmpbMvTAd0.jpg',
#   'photo_big': 'https://pp.userapi.com/c630725/v630725994/41047/0o-7aWfsJZk.jpg',
#   'photo_medium': 'https://pp.userapi.com/c630725/v630725994/41048/yVm5d6BL0CM.jpg',
#   'screen_name': 'kudrovorealty',
#   'type': 'page'}]

# %%
# записываем в файл
# with open('total_user_groupe.json','w', encoding="utf-8") as f:
#     f.write('[\n')
#     i = 0
#     n = 0
#     for group in final_unique_groups_user:
#         f.write('  {\n')
#         for key,val in group.items():
#             n = n + 1
#             if (n == len(group)):
#                 f.write('  "{}":"{}"\n'.format(key,val))
#             else:
#                 f.write('  "{}":"{}",\n'.format(key,val))
#         i = i + 1
#         if i == len(final_unique_groups_user):
#             f.write('  }\n')
#         else:
#             f.write('  },\n')            
#         f.write(']\n')

# %%
def write_json_file():
    with open('total_user_groupe.json','w', encoding="utf-8") as f:
        json.dump(final_unique_groups_user, f, sort_keys=True, indent=2, ensure_ascii=False) 
        print('----')
        f.close()

# %%
write_json_file()
# Out:
# ----
